# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import rc
rc('font', size=14)
rc('font', family='Arial')
# rc('font', serif='Times')
rc('pdf', fonttype=42)
# rc('text', usetex=True)

# %%
def lighten_color(color, amount=0.5):
    """
    Lightens the given color by multiplying (1-luminosity) by the given amount.
    Input can be matplotlib color string, hex string, or RGB tuple.

    Examples:
    >> lighten_color('g', 0.3)
    >> lighten_color('#F034A3', 0.6)
    >> lighten_color((.3,.55,.1), 0.5)
    """
    import matplotlib.colors as mc
    import colorsys
    try:
        c = mc.cnames[color]
    except:
        c = color
    c = colorsys.rgb_to_hls(*mc.to_rgb(c))
    return colorsys.hls_to_rgb(c[0], 1 - amount * (1 - c[1]), c[2])

# %%
folder = os.path.join('Y:',os.sep,'Nicola_Gritti','analysis_code','scRNAseq_Gastruloids','new_codes','results','integration','pijuan_anlas_useNN')

# %%
umap = pd.read_csv(os.path.join(folder,'integration_umap.csv'))
umap['cellname'] = umap.index
umap = umap.reset_index()

# %%
umap
# Out:
#                          index        V1         V2                cellname
# 0                       cell_1  0.383419   5.249228                  cell_1
# 1                       cell_2 -3.348407   3.917569                  cell_2
# 2                       cell_3 -2.452266 -12.011651                  cell_3
# 3                       cell_4 -0.560195   8.484165                  cell_4
# 4                       cell_5  1.348483   7.134074                  cell_5
# ...                        ...       ...        ...                     ...
# 136341  h72_TTTGTTGCACTCCTGT-1 -3.419316  -1.992867  h72_TTTGTTGCACTCCTGT-1
# 136342  h72_TTTGTTGCAGCGATTT-1  7.177235   0.285251  h72_TTTGTTGCAGCGATTT-1
# 136343  h72_TTTGTTGCATGCCGCA-1  2.191742  -3.435134  h72_TTTGTTGCATGCCGCA-1
# 136344  h72_TTTGTTGGTCGTATGT-1  7.112209   1.891344  h72_TTTGTTGGTCGTATGT-1
# 136345  h72_TTTGTTGTCAATCTCT-1  4.536007  -0.991022  h72_TTTGTTGTCAATCTCT-1
#
# [136346 rows x 4 columns]

# %%
meta_anlas = pd.read_csv(os.path.join(folder,'meta_anlas.csv'))
meta_pijuan = pd.read_csv(os.path.join(folder,'meta_pijuan.csv'))

meta_anlas['dataset'] = 'anlas'
meta_pijuan['dataset'] = 'pijuan'

meta = pd.concat([meta_pijuan,meta_anlas], ignore_index=True)
meta = meta[['celltype.general','batch.ident','celltype.anlas','celltype.pijuan','stage','merge.ident','dataset']]

meta = meta.rename(columns={'celltype.general':'celltype',
                            'celltype.anlas':'celltype_anlas',
                            'celltype.pijuan':'celltype_pijuan',
                            'merge.ident':'stage_anlas',
                            'stage':'stage_pijuan',
                            'batch.ident':'batch_ident'})
cellname = list(meta_pijuan.index)+list(meta_anlas.index)

meta['cellname'] = cellname

# %%
meta
# Out:
#                 celltype          batch_ident                  celltype_anlas  \
# 0               Epiblast  pijuan_E6.5_sample1                             NaN
# 1       Primitive Streak  pijuan_E6.5_sample1                             NaN
# 2                    ExE  pijuan_E6.5_sample1                             NaN
# 3               Epiblast  pijuan_E6.5_sample1                             NaN
# 4               Epiblast  pijuan_E6.5_sample1                             NaN
# ...                  ...                  ...                             ...
# 136341      G Early diff       anlas_72h_rep1    Early diff (SMAD, ERK activ)
# 136342      G Mesodermal       anlas_72h_rep1  Mesodermal (mesench & cardiac)
# 136343      G Mesodermal       anlas_72h_rep1     Mesodermal trunk and neural
# 136344      G Mesodermal       anlas_72h_rep1                      Mesodermal
# 136345      G Mesodermal       anlas_72h_rep1           Mesodermal (paraxial)
#
#          celltype_pijuan stage_pijuan stage_anlas dataset  \
# 0               Epiblast         E6.5         NaN  pijuan
# 1       Primitive Streak         E6.5         NaN  pijuan
# 2           ExE ectoderm         E6.5         NaN  pijuan
# 3               Epiblast         E6.5         NaN  pijuan
# 4               Epiblast         E6.5         NaN  pijuan
# ...                  ...          ...         ...     ...
# 136341               NaN          NaN         72h   anlas
# 136342               NaN          NaN         72h   anlas
# 136343               NaN          NaN         72h   anlas
# 136344               NaN          NaN         72h   anlas
# 136345               NaN          NaN         72h   anlas
#
#                       cellname
# 0                       cell_1
# 1                       cell_2
# 2                       cell_3
# 3                       cell_4
# 4                       cell_5
# ...                        ...
# 136341  h72_TTTGTTGCACTCCTGT-1
# 136342  h72_TTTGTTGCAGCGATTT-1
# 136343  h72_TTTGTTGCATGCCGCA-1
# 136344  h72_TTTGTTGGTCGTATGT-1
# 136345  h72_TTTGTTGTCAATCTCT-1
#
# [136346 rows x 8 columns]

# %%
meta[meta.celltype_anlas=='Early vascular & endo']
# Out:
#             celltype     batch_ident         celltype_anlas celltype_pijuan  \
# 132928  G Mesodermal  anlas_72h_rep1  Early vascular & endo             NaN
# 133097  G Mesodermal  anlas_72h_rep1  Early vascular & endo             NaN
# 133171  G Mesodermal  anlas_72h_rep1  Early vascular & endo             NaN
# 133371  G Mesodermal  anlas_72h_rep1  Early vascular & endo             NaN
# 133567  G Mesodermal  anlas_72h_rep1  Early vascular & endo             NaN
# 133594  G Mesodermal  anlas_72h_rep1  Early vascular & endo             NaN
# 134075  G Mesodermal  anlas_72h_rep1  Early vascular & endo             NaN
# 134338  G Mesodermal  anlas_72h_rep1  Early vascular & endo             NaN
# 134432  G Mesodermal  anlas_72h_rep1  Early vascular & endo             NaN
# 134504  G Mesodermal  anlas_72h_rep1  Early vascular & endo             NaN
# 134519  G Mesodermal  anlas_72h_rep1  Early vascular & endo             NaN
# 134661  G Mesodermal  anlas_72h_rep1  Early vascular & endo             NaN
# 134867  G Mesodermal  anlas_72h_rep1  Early vascular & endo             NaN
# 134927  G Mesodermal  anlas_72h_rep1  Early vascular & endo             NaN
# 134945  G Mesodermal  anlas_72h_rep1  Early vascular & endo             NaN
# 134972  G Mesodermal  anlas_72h_rep1  Early vascular & endo             NaN
# 135155  G Mesodermal  anlas_72h_rep1  Early vascular & endo             NaN
# 135380  G Mesodermal  anlas_72h_rep1  Early vascular & endo             NaN
# 135656  G Mesodermal  anlas_72h_rep1  Early vascular & endo             NaN
# 135863  G Mesodermal  anlas_72h_rep1  Early vascular & endo             NaN
# 135879  G Mesodermal  anlas_72h_rep1  Early vascular & endo             NaN
# 135975  G Mesodermal  anlas_72h_rep1  Early vascular & endo             NaN
# 136037  G Mesodermal  anlas_72h_rep1  Early vascular & endo             NaN
#
#        stage_pijuan stage_anlas dataset                cellname
# 132928          NaN         72h   anlas  h72_AACGTCAAGTCCGCCA-1
# 133097          NaN         72h   anlas  h72_ACCTACCAGCACCTGC-1
# 133171          NaN         72h   anlas  h72_ACTATTCGTATCGTAC-1
# 133371          NaN         72h   anlas  h72_AGGCTGCTCCTTATGT-1
# 133567          NaN         72h   anlas  h72_ATCTCTACAATCCAGT-1
# 133594          NaN         72h   anlas  h72_ATGGAGGCATCCAACA-1
# 134075          NaN         72h   anlas  h72_CCTCTAGTCCCAAGTA-1
# 134338          NaN         72h   anlas  h72_CTCCATGGTTCCGGTG-1
# 134432          NaN         72h   anlas  h72_CTGTAGAAGGATTCCT-1
# 134504          NaN         72h   anlas  h72_GAAATGATCGCCTATC-1
# 134519          NaN         72h   anlas  h72_GAAGCCCAGCCGTTGC-1
# 134661          NaN         72h   anlas  h72_GAGTTACAGGCGTTGA-1
# 134867          NaN         72h   anlas  h72_GCTCAAACACTCAAGT-1
# 134927          NaN         72h   anlas  h72_GGAGGTACAGAACATA-1
# 134945          NaN         72h   anlas  h72_GGCGTCAGTGTCGCTG-1
# 134972          NaN         72h   anlas  h72_GGGAGTAGTCTCAAGT-1
# 135155          NaN         72h   anlas  h72_GTCACTCAGGAACTCG-1
# 135380          NaN         72h   anlas  h72_TAACTTCCACGCTGCA-1
# 135656          NaN         72h   anlas  h72_TCCGGGACAATAGAGT-1
# 135863          NaN         72h   anlas  h72_TGAGGGAAGGTAAGAG-1
# 135879          NaN         72h   anlas  h72_TGATCTTAGAAGTCTA-1
# 135975          NaN         72h   anlas  h72_TGGATCATCATCCTGC-1
# 136037          NaN         72h   anlas  h72_TGTACAGTCCCAATAG-1

# %%
# generate the replicate and stage columns

reps = []
for i in meta.batch_ident:
    if 'rep1' in i:
        reps.append('rep1')
    elif 'rep2' in i:
        reps.append('rep2')
    else:
        reps.append(np.nan)
meta['replicate'] = reps

meta = meta.replace(np.nan, 'None', regex=True)
stage = []
for i in range(len(meta.celltype)):
    sa = meta.stage_anlas[i]
    sp = meta.stage_pijuan[i]
    if sa=='None':
        stage.append(sp)
    else:
        stage.append(sa)
meta['stage'] = stage

# %%
# combine umap and metadata dataframes

df = pd.concat([umap,meta], axis=1)

# %%
df
# Out:
#                          index        V1         V2                cellname  \
# 0                       cell_1  0.383419   5.249228                  cell_1
# 1                       cell_2 -3.348407   3.917569                  cell_2
# 2                       cell_3 -2.452266 -12.011651                  cell_3
# 3                       cell_4 -0.560195   8.484165                  cell_4
# 4                       cell_5  1.348483   7.134074                  cell_5
# ...                        ...       ...        ...                     ...
# 136341  h72_TTTGTTGCACTCCTGT-1 -3.419316  -1.992867  h72_TTTGTTGCACTCCTGT-1
# 136342  h72_TTTGTTGCAGCGATTT-1  7.177235   0.285251  h72_TTTGTTGCAGCGATTT-1
# 136343  h72_TTTGTTGCATGCCGCA-1  2.191742  -3.435134  h72_TTTGTTGCATGCCGCA-1
# 136344  h72_TTTGTTGGTCGTATGT-1  7.112209   1.891344  h72_TTTGTTGGTCGTATGT-1
# 136345  h72_TTTGTTGTCAATCTCT-1  4.536007  -0.991022  h72_TTTGTTGTCAATCTCT-1
#
#                 celltype          batch_ident                  celltype_anlas  \
# 0               Epiblast  pijuan_E6.5_sample1                            None
# 1       Primitive Streak  pijuan_E6.5_sample1                            None
# 2                    ExE  pijuan_E6.5_sample1                            None
# 3               Epiblast  pijuan_E6.5_sample1                            None
# 4               Epiblast  pijuan_E6.5_sample1                            None
# ...                  ...                  ...                             ...
# 136341      G Early diff       anlas_72h_rep1    Early diff (SMAD, ERK activ)
# 136342      G Mesodermal       anlas_72h_rep1  Mesodermal (mesench & cardiac)
# 136343      G Mesodermal       anlas_72h_rep1     Mesodermal trunk and neural
# 136344      G Mesodermal       anlas_72h_rep1                      Mesodermal
# 136345      G Mesodermal       anlas_72h_rep1           Mesodermal (paraxial)
#
#          celltype_pijuan stage_pijuan stage_anlas dataset  \
# 0               Epiblast         E6.5        None  pijuan
# 1       Primitive Streak         E6.5        None  pijuan
# 2           ExE ectoderm         E6.5        None  pijuan
# 3               Epiblast         E6.5        None  pijuan
# 4               Epiblast         E6.5        None  pijuan
# ...                  ...          ...         ...     ...
# 136341              None         None         72h   anlas
# 136342              None         None         72h   anlas
# 136343              None         None         72h   anlas
# 136344              None         None         72h   anlas
# 136345              None         None         72h   anlas
#
#                       cellname replicate stage
# 0                       cell_1      None  E6.5
# 1                       cell_2      None  E6.5
# 2                       cell_3      None  E6.5
# 3                       cell_4      None  E6.5
# 4                       cell_5      None  E6.5
# ...                        ...       ...   ...
# 136341  h72_TTTGTTGCACTCCTGT-1      rep1   72h
# 136342  h72_TTTGTTGCAGCGATTT-1      rep1   72h
# 136343  h72_TTTGTTGCATGCCGCA-1      rep1   72h
# 136344  h72_TTTGTTGGTCGTATGT-1      rep1   72h
# 136345  h72_TTTGTTGTCAATCTCT-1      rep1   72h
#
# [136346 rows x 14 columns]

# %%
df1 = df[df.dataset=='pijuan']
# df1 = df1.sample(n=10000, random_state=1)

# %%
mousetype_order = ['Epiblast','Primitive Streak','Endoderm','Ectoderm','Mesoderm','PGC','ExE']
anlastype_order = ['G Pluripotent','G Primed pluripotent','G Early diff','G Endodermal',
                   'G Neural','G Mesodermal','G Mesendodermal']

cp = sns.color_palette("husl", 7)
cp = [lighten_color(i,0.25) for i in cp]
ca = sns.color_palette("Paired")
ca = [(0.,0.,0.),ca[1],ca[3],ca[5],ca[7],ca[11],ca[9]]

# %% [markdown]
# # All cell types

# %%
df2 = df[df.dataset=='anlas']

fig, ax = plt.subplots(figsize=(10,6))
fig.subplots_adjust(left=0.15, right=0.6, top=0.9, bottom=0.15)

sns.scatterplot(data=df1, x='V1', y='V2',
                s=20,
                hue='celltype', 
                hue_order=mousetype_order,
                palette = cp,
                linewidth=0, alpha=1., 
                edgecolors='none',
                ax=ax,
                rasterized=True
               )
ax.set_xlabel('UMAP 1')
ax.set_ylabel('UMAP 2')

ax.set_xticks([])
ax.set_yticks([])

ax.set_title('Pijuan vs Gastruloids All Fates')

plt.legend(frameon=False,bbox_to_anchor=(1.05, 1))

#fig.savefig(os.path.join(folder,'pijuanFate_vs_gastrFateAll.pdf'), dpi=600)

# %%
df2 = df[df.dataset=='anlas']

fig, ax = plt.subplots(figsize=(10,6))
fig.subplots_adjust(left=0.15, right=0.6, top=0.9, bottom=0.15)

sns.scatterplot(data=df1, x='V1', y='V2',
                s=20,
                hue='celltype', 
                hue_order=mousetype_order,
                palette = cp,
                linewidth=0, alpha=1., 
                edgecolors='none',
                ax=ax,
                rasterized=True
               )
sns.scatterplot(data=df2, x='V1', y='V2',
                s=3,
                hue='celltype', 
                hue_order=anlastype_order,
                palette = ca,
                linewidth=0, alpha=1., 
                edgecolors='none',
                ax=ax,
                rasterized=True
               )
ax.set_xlabel('UMAP 1')
ax.set_ylabel('UMAP 2')

ax.set_xticks([])
ax.set_yticks([])

ax.set_title('Pijuan vs Gastruloids All Fates')

plt.legend(frameon=False,bbox_to_anchor=(1.05, 1))

fig.savefig(os.path.join(folder,'pijuanFate_vs_gastrFateAll.pdf'), dpi=600)

# %%
df2 = df[(df.dataset=='anlas')&((df.celltype=='G Pluripotent')|(df.celltype=='G Primed pluripotent'))]
   
fig, ax = plt.subplots(figsize=(10,6))
fig.subplots_adjust(left=0.15, right=0.6, top=0.9, bottom=0.15)

sns.scatterplot(data=df1, x='V1', y='V2',
                s=20,
                hue='celltype', 
                hue_order=mousetype_order,
                palette = cp,
                linewidth=0, alpha=1., 
                ax=ax,
                rasterized=True)
sns.scatterplot(data=df2, x='V1', y='V2',
                s=5,
                hue='celltype', 
                hue_order=['G Pluripotent','G Primed pluripotent'],
                palette = ca[:2],
                linewidth=0, alpha=1., 
                ax=ax,
                rasterized=True)

ax.set_xlabel('UMAP 1')
ax.set_ylabel('UMAP 2')

ax.set_xticks([])
ax.set_yticks([])

ax.set_title('Pijuan vs Gastruloids Pluripotent')

plt.legend(frameon=False,bbox_to_anchor=(1.05, 1))

fig.savefig(os.path.join(folder,'pijuanFate_vs_gastrFate1.pdf'), dpi=600)

# %%
df2 = df[(df.dataset=='anlas')&((df.celltype=='G Early diff')|(df.celltype=='G Neural'))]
   
fig, ax = plt.subplots(figsize=(10,6))
fig.subplots_adjust(left=0.15, right=0.6, top=0.9, bottom=0.15)

sns.scatterplot(data=df1, x='V1', y='V2',
                s=20,
                hue='celltype', 
                hue_order=mousetype_order,
                palette = cp,
                linewidth=0, alpha=1., 
                ax=ax,
                rasterized=True)
sns.scatterplot(data=df2, x='V1', y='V2',
                s=5,
                hue='celltype',
                color='k',
                hue_order=['G Early diff','G Neural'],
                palette = [ca[2],ca[4]],
                linewidth=0, alpha=1., 
                ax=ax,
                rasterized=True)

ax.set_xlabel('UMAP 1')
ax.set_ylabel('UMAP 2')

ax.set_xticks([])
ax.set_yticks([])

ax.set_title('Pijuan vs Gastruloids Early diff')

plt.legend(frameon=False,bbox_to_anchor=(1.05, 1))

fig.savefig(os.path.join(folder,'pijuanFate_vs_gastrFate2.pdf'), dpi=600)

# %%
df2 = df[(df.dataset=='anlas')&((df.celltype=='G Endodermal')|(df.celltype=='G Mesodermal')|(df.celltype=='G Mesendodermal'))]
   
fig, ax = plt.subplots(figsize=(10,6))
fig.subplots_adjust(left=0.15, right=0.6, top=0.9, bottom=0.15)

sns.scatterplot(data=df1, x='V1', y='V2',
                s=20,
                hue='celltype', 
                hue_order=mousetype_order,
                palette = cp,
                linewidth=0, alpha=1., 
                ax=ax,
                rasterized=True)
sns.scatterplot(data=df2, x='V1', y='V2',
                s=5,
                hue='celltype',
                color='k',
                hue_order=['G Endodermal','G Mesodermal','G Mesendodermal'],
                palette = [ca[3],ca[5],ca[6]],
                linewidth=0, alpha=1., 
                ax=ax,
                rasterized=True)

ax.set_xlabel('UMAP 1')
ax.set_ylabel('UMAP 2')

ax.set_xticks([])
ax.set_yticks([])

ax.set_title('Pijuan vs Gastruloids Diff')

plt.legend(frameon=False,bbox_to_anchor=(1.05, 1))

fig.savefig(os.path.join(folder,'pijuanFate_vs_gastrFate3.pdf'), dpi=600)

# %% [markdown]
# # Anlas Stage

# %%
ca_stage = sns.color_palette("rocket")
ca_stage  =[ca_stage[0],ca_stage[2],ca_stage[4]]

# %%
fig, ax = plt.subplots(figsize=(10,6))
fig.subplots_adjust(left=0.15, right=0.6, top=0.9, bottom=0.15)

g1 = sns.scatterplot(data=df1, x='V1', y='V2',
                s=20,
                hue='celltype', 
                hue_order=mousetype_order,
                palette = cp,
                linewidth=0, alpha=1., 
                ax=ax,
                rasterized=True)
g2 = sns.scatterplot(data=df[(df.dataset=='anlas')], x='V1', y='V2',
                s=1.,
                hue='stage_anlas',
                palette = ca_stage,
                linewidth=0, alpha=1., 
                ax=ax,
                rasterized=True)

ax.set_xlabel('UMAP 1')
ax.set_ylabel('UMAP 2')

ax.set_xticks([])
ax.set_yticks([])

ax.set_title('Pijuan vs GastruloidsAllStages')

plt.legend(frameon=False,bbox_to_anchor=(1.05, 1))

fig.savefig(os.path.join(folder,'pijuanFate_vs_gastrStageAll.pdf'), dpi=600)

# %%
df2 = df[(df.dataset=='anlas')&(df.stage_anlas=='24h')]

fig, ax = plt.subplots(figsize=(10,6))
fig.subplots_adjust(left=0.15, right=0.6, top=0.9, bottom=0.15)

g1 = sns.scatterplot(data=df1, x='V1', y='V2',
                s=20,
                hue='celltype', 
                hue_order=mousetype_order,
                palette = cp,
                linewidth=0, alpha=1., 
                ax=ax,
                rasterized=True)
g2 = sns.scatterplot(data=df2, x='V1', y='V2',
                s=5,
#                 hue='replicate',
                color = ca_stage[0],
                linewidth=0, alpha=1.,
                edgecolors='none',
                ax=ax,
                rasterized=True)

ax.set_xlabel('UMAP 1')
ax.set_ylabel('UMAP 2')

ax.set_xticks([])
ax.set_yticks([])

ax.set_title('Pijuan vs Gastruloids24h')

plt.legend(frameon=False,bbox_to_anchor=(1.05, 1))

fig.savefig(os.path.join(folder,'pijuanFate_vs_gastrStage24h.pdf'), dpi=600)

# %%
df2 = df[(df.dataset=='anlas')&(df.stage_anlas=='48h')]

fig, ax = plt.subplots(figsize=(10,6))
fig.subplots_adjust(left=0.15, right=0.6, top=0.9, bottom=0.15)

g1 = sns.scatterplot(data=df1, x='V1', y='V2',
                s=20,
                hue='celltype', 
                hue_order=mousetype_order,
                palette = cp,
                linewidth=0, alpha=1., 
                ax=ax,
                rasterized=True)
g2 = sns.scatterplot(data=df2, x='V1', y='V2',
                s=5,
#                 hue='replicate',
                color = ca_stage[1],
                linewidth=0, alpha=1., 
                ax=ax,
                rasterized=True)                     

ax.set_xlabel('UMAP 1')
ax.set_ylabel('UMAP 2')

ax.set_xticks([])
ax.set_yticks([])

ax.set_title('Pijuan vs Gastruloids48h')

plt.legend(frameon=False,bbox_to_anchor=(1.05, 1))

fig.savefig(os.path.join(folder,'pijuanFate_vs_gastrStage48h.pdf'), dpi=600)

# %%
df2 = df[(df.dataset=='anlas')&(df.stage_anlas=='72h')]

fig, ax = plt.subplots(figsize=(10,6))
fig.subplots_adjust(left=0.15, right=0.6, top=0.9, bottom=0.15)

g1 = sns.scatterplot(data=df1, x='V1', y='V2',
                s=20,
                hue='celltype', 
                hue_order=mousetype_order,
                palette = cp,
                linewidth=0, alpha=1., 
                ax=ax,
                rasterized=True)
g2 = sns.scatterplot(data=df2, x='V1', y='V2',
                s=5,
#                 hue='replicate',
                color = ca_stage[2],
                linewidth=0, alpha=1., 
                ax=ax,
                rasterized=True)

ax.set_xlabel('UMAP 1')
ax.set_ylabel('UMAP 2')

ax.set_xticks([])
ax.set_yticks([])

ax.set_title('Pijuan vs Gastruloids72h')

plt.legend(frameon=False,bbox_to_anchor=(1.05, 1))

fig.savefig(os.path.join(folder,'pijuanFate_vs_gastrStage72h.pdf'), dpi=600)

# %% [markdown]
# # Use nearest neighbor cells

# %%
corrected = pd.read_csv(os.path.join(folder,'integration.csv'))

# %%
pijuan_idx = ['cell' in i for i in corrected.index]

# %%
corrected_pijuan = corrected[pijuan_idx]
corrected_anlas = corrected[[not i for i in pijuan_idx]]

meta_pijuan = meta[pijuan_idx]
meta_anlas = meta[[not i for i in pijuan_idx]]

# %%
from sklearn.neighbors import NearestNeighbors
nbrs = NearestNeighbors(n_neighbors=30, algorithm='ball_tree').fit(corrected_pijuan)
distances, indices = nbrs.kneighbors(corrected_anlas)

# %%
dist = np.mean(distances,1)

d = pd.DataFrame({'distance':dist,'gtype':list(meta_anlas.celltype)})


fig, ax = plt.subplots(figsize=(10,5))
fig.subplots_adjust(left=0.15, right=0.6, top=0.9, bottom=0.15)
sns.violinplot(data=d, y="distance", x="gtype", ax=ax, scale='width', palette=ca,
               order=anlastype_order)
ax.set_xticklabels(anlastype_order, rotation=45, ha='right')
# for tick in ax.get_xticklabels():
#     tick.set_rotation(45)
ax.set_ylim(0,17)
ax.set_xlabel('Gastruloid cell type')
# Out:
# Text(0.5, 0, 'Gastruloid cell type')

# %%
# cells lost
loss = []
n_gcs = []
n_mcs = []
for ct in anlastype_order:
    n_gc = len(indices[meta_anlas.celltype==ct,0])
    n_mc = len(set(indices[meta_anlas.celltype==ct,0]))
    print(ct,n_gc,n_mc,'%.5f'%(n_mc/n_gc))
    loss.append(n_mc/n_gc)
    n_mcs.append(n_mc)
    n_gcs.append(n_gc)

d = pd.DataFrame({'celltype':anlastype_order,'loss':loss})

fig, ax = plt.subplots(figsize=(10,5))
fig.subplots_adjust(left=0.15, right=0.6, top=0.9, bottom=0.15)
sns.barplot(data=d, y="loss", x="celltype", ax=ax, palette=ca,
               order=anlastype_order)
ax.set_xticklabels(anlastype_order, rotation=45, ha='right')
# for tick in ax.get_xticklabels():
#     tick.set_rotation(45)
ax.set_ylim(0,1)
ax.set_xlabel('Gastruloid cell type')
ax.set_ylabel('Cell loss percentage')

for i in range(len(n_gcs)):
    ax.text(-0.25+i,0.1,'%.1f%%'%(100*n_mcs[i]/n_gcs[i]), fontsize=10)
    ax.text(-0.25+i,0.15,'%d'%(n_gcs[i]), fontsize=10)
# Out:
# G Pluripotent 4051 188 0.04641
# G Primed pluripotent 2917 1170 0.40110
# G Early diff 2435 1153 0.47351
# G Endodermal 637 381 0.59812
# G Neural 1506 580 0.38513
# G Mesodermal 6686 2752 0.41161
# G Mesendodermal 1802 948 0.52608

# %%
cells = df[df.dataset=='pijuan'].iloc[list(indices[:,0])]
cells['type_anlas'] = list(df[df.dataset=='anlas'].celltype)
cells = cells.reset_index()

# %%
fig, ax = plt.subplots(figsize=(10,6))
fig.subplots_adjust(left=0.15, right=0.6, top=0.9, bottom=0.15)

sns.scatterplot(data=df1, x='V1', y='V2',
                s=20,
                hue='celltype', 
                hue_order=mousetype_order,
                palette=cp,
                linewidth=0, alpha=1., 
                edgecolors='none',
                ax=ax,
                rasterized=True
               )
g2 = sns.scatterplot(data=cells, x='V1', y='V2',
                s=5,
                hue='type_anlas',
                hue_order=anlastype_order,
                palette=ca,
                linewidth=0, alpha=1.,
                edgecolors='none',
                ax=ax,
                rasterized=True)
ax.set_xlabel('UMAP 1')
ax.set_ylabel('UMAP 2')

ax.set_xticks([])
ax.set_yticks([])

ax.set_title('Pijuan vs Gastruloids All Fates')

plt.legend(frameon=False,bbox_to_anchor=(1.05, 1))

#fig.savefig(os.path.join(folder,'pijuanFate_vs_gastrFateAll.pdf'), dpi=600)

# %%
fig, ax = plt.subplots(figsize=(10,6))
fig.subplots_adjust(left=0.15, right=0.6, top=0.9, bottom=0.15)

sns.scatterplot(data=df1, x='V1', y='V2',
                s=20,
                hue='celltype', 
                hue_order=mousetype_order,
                palette=cp,
                linewidth=0, alpha=1., 
                edgecolors='none',
                ax=ax,
                rasterized=True
               )
g2 = sns.scatterplot(data=cells[cells.type_anlas=='G Pluripotent'], x='V1', y='V2',
                s=1,
                hue='type_anlas',
                hue_order=anlastype_order,
                palette=ca,
                linewidth=0, alpha=1.,
                edgecolors='none',
                ax=ax,
                rasterized=True)
ax.set_xlabel('UMAP 1')
ax.set_ylabel('UMAP 2')

ax.set_xticks([])
ax.set_yticks([])

ax.set_title('Pijuan vs Gastruloids All Fates')

plt.legend(frameon=False,bbox_to_anchor=(1.05, 1))

#fig.savefig(os.path.join(folder,'pijuanFate_vs_gastrFateAll.pdf'), dpi=600)
